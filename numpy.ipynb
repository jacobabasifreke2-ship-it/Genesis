# %%
def chat(name, address, track, amount = 3454):
    print("Welcome Mr " + name +" do you still live at " + address + " ,your track is still " + track)

chat("Mike", "Estate 6", "Web Dev")
# Out:
# Welcome Mr Mike do you still live at Estate 6 ,your track is still Web Dev

# %%
for man in (1,2,3,4,5,6,7,8,9,0):
    print(man)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 0

# %%
x = 1
while x <= 5:
    print(x)
    x += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for car in range(2, 15, 4):
    print(car)
# Out:
# 2
# 6
# 10
# 14

# %%
address = "grace bill road eket"
address.lower()
address.title()
address.upper()
address.split()
# Out:
# ['grace', 'bill', 'road', 'eket']

# %%
fruit = "watermelon"
fruit.startswith("w")
# Out:
# True

# %%
name = "Jacob Paul"
age = 55
jkl = name.replace("Jacob", "Abas")
print(jkl)
# Out:
# Abas Paul

# %%
print("My name is {} and I am {} years old ").__format__
# Out:
# My name is {} and I am {} years old
# <function NoneType.__format__(self, format_spec, /)>

# %% [markdown]
# These are methods:
# .len()
# .sum()
# .type()
# .min()
# .max()

# %%
marks_1 = (23, 23, "absent", 35, "missing", 89)
items = ("mat", "cup",)

# %%
A = {4,2,3,9}
B = {4,5,2,1}
C = B - A
C
# Out:
# {1, 5}

# %%
top_sports = {
    "Alex": "Football",
    "Joyy": "Basketball",
    "Dan": "Tennis"
}

# %% [markdown]
# ### Numpy
#
# * It is a libary (collection of already written codes)
# * It helps us to work with numbers
# * It allows fast mathematical operations in big amounts of data

# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5,6])

arr1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
c = np.array([2,4,6,8])
d = np.array([3,6,9,9])

print( c + d)
# Out:
# [ 5 10 15 17]

# %%
c.size
# Out:
# 4

# %%
c.dtype
# Out:
# dtype('int64')

# %%
big_num = c[c > 2]
big_num
# Out:
# array([4, 6, 8])

# %%
#Matrix is a 2D table of numbers
A = np.array([[9,7,6,5],
              [4,6,5,1]])

B = np.array([[5,6],         
              [7,8]])

print(A.shape)
print(A.size)
# Out:
# (2, 4)
# 8

# %%
print(np.sum(A))
print(np.mean(A))
print(np.transpose(A))
# Out:
# 43
# 5.375
# [[9 4]
#  [7 6]
#  [6 5]
#  [5 1]]

# %%
np.where(A > 5, "So High","Low")
# Out:
# array([['So High', 'So High', 'So High', 'Low'],
#        ['Low', 'So High', 'Low', 'Low']], dtype='<U7')

# %%
print(np.random.rand(2,3))
print(np.random.randint(15,89,12))
# Out:
# [[0.30162582 0.56064051 0.90666182]
#  [0.55341444 0.12473305 0.01242958]]
# [71 84 32 55 63 54 38 16 66 67 78 27]

# %%
scores = np.array([[85,55,66],
                   [66,45,90],
                   [72,92,80]])

print("  M","  E","  S")

print(scores)
# Out:
#   M   E   S
# [[85 55 66]
#  [66 45 90]
#  [72 92 80]]

# %%
print(scores[:,2])
print(scores[1,1])
# Out:
# [66 90 80]
# 45

# %%
np.sum(scores[1,:])
# Out:
# np.int64(201)

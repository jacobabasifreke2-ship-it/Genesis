# %%
prompt = f"\nHello Welcome to Genesis Ciniema"
prompt += f"\nWe'll be showing 'Infinite' today"
prompt += f"\nAre you here alone or with company: "

ans1 = ("Enter your age(s) to know the cost of your movie ticket: ")
ans2 = ("What is the number of your companions: ")


data = input(prompt)
if data == "alone" or "Alone":
      message = int(input(ans1))

#     print(input(ans1))
elif data == "company","with company","Company":
    info = int(input(ans2))

    if info <= 9:
        message = int(input(ans1))
    elif info > 9:
        print("Sorry but we do not have seats available for that number!")
        
    else:
        print("Please enter the number of your companions")
else:
    print("Please choose a vaild option!")
    
    

#perform another check

if message < 3:
        print("Congratulations young one your ticket is free")
elif message < 12:
        print("Your ticket costs only $10")
elif message < 18:
        print("Your ticket costs only $15")
elif message < 30:
        print("Your ticket costs only $20")
elif message < 85:
        print("Your ticket costs only $25")
elif message <= 101:
        print("Your ticket costs only $10")
elif message > 101:
        print("Please enter a valid age")
else:
        print("Kindly enter a valid number")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 11
#       7
#       8
#       9 data = input(prompt)
#      10 if data == "alone" or "Alone":
# ---> 11       message = int(input(ans1))
#      12
#      13 #     print(input(ans1))
#      14 elif data == "company" or "with company" or "Company":
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# prompt = f"\nHello Welcome to Genesis Ciniema"
# prompt += f"\nWe'll be showing 'Infinite' today"
# prompt += f"\nAre you here alone or with company: "

# ans1 = ("Enter your age to know the cost of your movie ticket: ")
# ans2 = ("What is the number of your companions: ")
# data = input(prompt)
# info = int(input(ans2))
# message = int(input(ans1))


# # message = int(input(ans1))
# if data == "alone":
#     print(input(ans1))
# elif data == "company":
#     print(input(ans2))
# else:
#     print("Please choose a vaild option!")

#  #perform a check
# if info <= 9:
#     print("Enter your ages to know the costs of your movie tickets")
# else:
#     print("Please enter the number of your companions")

# #perform another check
# if message < 3:
#     print("Congratulations young one your ticket is free")
# elif message < 12:
#     print("Your ticket costs only $10")
# elif message < 18:
#     print("Your ticket costs only $15")
# elif message < 30:
#     print("Your ticket costs only $20")
# elif message < 85:
#     print("Your ticket costs only $25")
# elif message <= 101:
#     print("Your ticket costs only $10")
# elif message > 101:
#     print("Please enter a valid age")
# else:
#     print("Kindly enter a valid number")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       4
#       5 ans1 = ("Enter your age to know the cost of your movie ticket: ")
#       6 ans2 = ("What is the number of your companions: ")
#       7 data = input(prompt)
# ----> 8 info = int(input(ans2))
#       9 message = int(input(ans1))
#      10
#      11
#
# ValueError: invalid literal for int() with base 10: ''

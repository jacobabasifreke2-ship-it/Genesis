# %%
# prompt = "Enter your name "
# info =  "Enter your age"

# man = input(prompt)
# age = input(info)

# print(f"Hello {man.title()}")
# print(f"You are {age} years old nigga")
# Out:
# Hello Paul
# You are 45 years

# %%
prompt = "Hello and welcome to Levels"
prompt += f"\nPlease enter your username "
prompt += f"\nTo terminate program enter end!! "
service = True

man = input(prompt)
if man == "admin":
    right = input("Please enter password")
    if right == "python123":
        print("Welcome back user")
    elif man == "end":
        service = False
    else:
        print("Incorrect password")
elif man == "end":
    service = False
else:
    print("Invalid username")

# %%
man = "Jacob Abasifreke Linus"
len(man)
# Out:
# 22

# %%
# info = "Enter a number "
# ninfo = "+ - / *    "

# store = {}

# def calc(a b c):
#     print()

# den = int(input(info))

# den2 = input(ninfo)

# den3 = int(input(f"{den2} "))

# result = den {den2}, den3

# print(f"{result} = ")
# Out:
# 56 - 8 =

# %%
def calc():
    print("Greatest Invention of All Time")
   
    # Get input directly from user
    num1 = int(input("Enter first number: "))
    operator = input("Enter operator | + | - | * | / |: ")  # user types + - * /
    num2 = int(input("Enter second number: "))

    if operator == '+':
        result = num1 + num2
        print(f"{num1} + {num2} = {result}")

    elif operator == '-':
        result = num1 - num2
        print(f"{num1} - {num2} = {result}")

    elif operator == '*':
        result = num1 * num2
        print(f"{num1} * {num2} = {result}")

    elif operator == '/':
        if num2 != 0:
            result = num1 / num2
            print(f"{num1} / {num2} = {result}")
        else:
            print("Error: Cannot divide by zero")

    else:
        print("Invalid operator. Please use +, -, *, or /")

calc()
# Out:
# Greatest Invention of All Time
# Invalid operator. Please use +, -, *, or /

# %%
x = 1
while x <= 50:
    print(x)
    x += 1

# %%
import pandas as pd

# %%
#to link a document to python
hr = pd.read_csv("C:\\Users\\atavu-tech\\Documents\\Python Files\\StaffData.csv")

# %%
#to show the firsts
hr.head(8)
#to show the lasts
hr.tail(3)
#to know the number of columns and rows
hr.shape

# %%
#to give a detailed info of the data frame
hr.info()

# %%
hr.describe()

# %%
hr.columns

# %%
# to check the value at a location
hr.at[3,"last_name"]

# %%
# to generate random recorords from the data
hr.sample(3)

# %%
hr.loc[0]

# %%
#to show the values of a column
hr.last_name

# %%
#to replace a value
hr["Currency"] = hr["Currency"].replace({"Afghani":"CAD","Rupee":"Naira"})

# %%
m_20 = hr[hr["Earnings"]> 2000000]

# %%
m_20

# %%
cl = hr["Currency"].value_counts()
cl

# %%
# hr.drop(columns= ["Bank name"], inplace=True)
hr.sample(6)

# %%
# hr.drop(index= [241], inplace=True)hr
hr.loc[238: 245]

# %%
#this counts number of each unique value
no_of_peeps = hr["gender"].value_counts().sort_index()
no_of_peeps

# %%
hr.sample(2)

# %%
# hr["Earnings"] = hr["Earnings"].str.replace(".","", regex=False)
hr["Earnings"] = hr["Earnings"].astype(int)

# %%
#to calculate using sth similar to sumif
m_bal = hr[hr["gender"] == "Male"]["Earnings"].sum()

# %%
m_bal

# %%
#generating a new column by multiplying earnings by 0.035
hr["Tax"] = hr["Earnings"] * 0.035
hr["Tax"]

# %%
#tax amt when currency is euro
e_count =hr[ hr["Currency"] == "Euro"]["Tax"].sum()
e_count

# %%
t_count = hr[hr["Occupation"] == "Food Chemist"].shape[0]
t_count

# %%
#to rename a column
hr.rename(columns={"Earnings" : "Income"})

# %%
#to show all the values of a unique value in a column
graph = hr[hr["Occupation"] == "Food Chemist"]
graph

# %%
inc = hr.sort_values("Earnings", ascending = False)
inc
